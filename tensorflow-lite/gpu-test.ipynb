# %% [markdown]
# # CUDA 설치하기
# - 설치가이드
# > https://wordbe.tistory.com/entry/Windows-tensorflow-GPU-%EC%84%A4%EC%B9%98
# - driver설치할 때 notebook이 아닌 desktop version이 맞는지 꼭 확인하자
# - pip install tensorflow
# - pip install tensorflow-gpu

# %% [markdown]
# ### 1. nvidia driver만 설치했을 때
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. CUDA 설치후
# ![image.png](attachment:image.png)

# %%
from tensorflow.python.client import device_lib

# %%
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 2003411518905622681
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 303306647604476333
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 12663132434043853527
# physical_device_desc: "device: XLA_GPU device"
# ]

# %%
import tensorflow as tf 
print(tf.__version__) 
tf.test.is_gpu_available()
# Out:
# 2.3.0
# WARNING:tensorflow:From <ipython-input-1-2d4f945ed5c6>:3: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
