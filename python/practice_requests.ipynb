# %%
import requests

# %%
# 동이름 -> 위도 경도
addr='아현동'
url = 'https://apis.zigbang.com/search?q={}'.format(addr)
response = requests.get(url)
datas = response.json()["items"][0]
datas
# Out:
# {'id': 4013,
#  'type': 'address',
#  'name': '아현동',
#  'hint': '',
#  'description': '서울시 마포구 아현동',
#  'lat': 37.55445861816406,
#  'lng': 126.95697021484375,
#  'zoom': 5,
#  'polygon': [],
#  '_score': None,
#  '_source': {'name_length': 3,
#   'local1': '서울시',
#   'local2': '마포구',
#   'local3': '아현동',
#   'web_level': 15,
#   'web_lat': 37.55445861816406,
#   'web_lng': 126.95697021484375,
#   'app_level': 15,
#   'app_lat': 37.55445861816406,
#   'app_lng': 126.95697021484375,
#   '법정동코드': '1144010100'},
#  'zoom_level': {'google': 15, 'daum': 4},
#  'zoom_level_v2': {'app': 5, 'web': 4}}

# %%
lat,lng =datas["lat"],datas["lng"]
lat,lng
# Out:
# (37.55445861816406, 126.95697021484375)

# %%
#위도, 경도 -> geohash

# %%
import geohash2
geohash= geohash2.encode(lat,lng, 5)
lat, lng, geohash
# Out:
# (37.55445861816406, 126.95697021484375, 'wydm8')

# %%
#geohash -> ids
url='https://apis.zigbang.com/property/apartments/items?domain=zigbang&geohash={}&q=type=sales|price=0~-1|floorArea=0~-1'.format(geohash)
response=requests.get(url)
datas =  response.json()["items"]
ids= [data["itemId"] for data in datas]
len(datas), ids[:3]
# Out:
# (1569, [18831263, 18833465, 18833493])

# %%
datas[0]
# Out:
# {'itemId': 18831263,
#  'lat': 37.54692410332956,
#  'lng': 126.924363546218,
#  'created_at': '2019-11-09 11:04:53'}

# %%
# 주소에 str로 들어가야하기 때문에(request할 헤더에)
ids_str = str(ids[:200]).replace(" ","")

# %%
# ids->items
url = "https://apis.zigbang.com/property/apartments/items?\vritemIds={ids}&itemIds={ids}&citemIds={ids}".format(ids=ids_str)
response = requests.get(url)
datas= response.json()['items']
datas
# Out:
# [{'itemId': 18831263,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54692410332956,
#   'lng': 126.924363546218,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '거실확장 화장실, 바닥, 수납공간수리 주인거주',
#   'agentNo': 48819,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T08:17:17.000Z',
#   'apartmentId': 9059,
#   'apartmentName': '상수두산위브',
#   'buildingName': '102동',
#   'roomTypeId': 11615,
#   'grossAreaName': {'m2': 104, 'p': 31},
#   'grossArea': {'m2': 104, 'p': 31},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/9059/11615/a8a9c926d5124180b7ce3f4e52b6da56.png',
#   'userNo': 5257440,
#   'agentId': 5257440,
#   'agentName': '래미안부동산공인중개사사무소',
#   'agentTel': '01087675775',
#   'agentUserName': '임소기',
#   'agentPhone': '01045825924',
#   'created_at': '2019-11-09 11:04:53',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/9059/11615/a8a9c926d5124180b7ce3f4e52b6da56.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 104, 'p': 31},
#   'isNew': True,
#   'sales': 103000},
#  {'itemId': 18833465,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '33',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.572898864746094,
#   'lng': 126.91799926757812,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '입주가능 확장형.가재울초.주인거주 깨끗하게 관리',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T08:12:18.000Z',
#   'apartmentId': 33297,
#   'apartmentName': 'DMC파크뷰자이1단지',
#   'buildingName': '106동',
#   'roomTypeId': 91742,
#   'grossAreaName': {'m2': 87, 'p': 26},
#   'grossArea': {'m2': 87, 'p': 26},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'http://s.zigbang.com/v2/web/danji/area_empty.jpg',
#   'userNo': 5213571,
#   'agentId': 5213571,
#   'agentName': '수부동산공인중개사사무소',
#   'agentTel': '023244242',
#   'agentUserName': '백윤념',
#   'agentPhone': '01097731199',
#   'created_at': '2019-11-09 12:39:13',
#   'real_type': '아파트',
#   'itemImage': ['http://s.zigbang.com/v2/web/danji/area_empty.jpg'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 87, 'p': 26},
#   'isNew': True,
#   'sales': 90000},
#  {'itemId': 18833493,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '29',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.572898864746094,
#   'lng': 126.91799926757812,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '투자좋은물건.확장.혁신초 단지내.',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T08:12:03.000Z',
#   'apartmentId': 33297,
#   'apartmentName': 'DMC파크뷰자이1단지',
#   'buildingName': '114동',
#   'roomTypeId': 91742,
#   'grossAreaName': {'m2': 87, 'p': 26},
#   'grossArea': {'m2': 87, 'p': 26},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'http://s.zigbang.com/v2/web/danji/area_empty.jpg',
#   'userNo': 5213571,
#   'agentId': 5213571,
#   'agentName': '수부동산공인중개사사무소',
#   'agentTel': '023244242',
#   'agentUserName': '백윤념',
#   'agentPhone': '01097731199',
#   'created_at': '2019-11-09 12:40:36',
#   'real_type': '아파트',
#   'itemImage': ['http://s.zigbang.com/v2/web/danji/area_empty.jpg'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 87, 'p': 26},
#   'isNew': True,
#   'sales': 90000},
#  {'itemId': 18031982,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '19',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.56949108361799,
#   'lng': 126.91721400143786,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '가좌역. 생활권 편리',
#   'agentNo': 32647,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T08:03:49.000Z',
#   'apartmentId': 7753,
#   'apartmentName': '창덕에버빌',
#   'buildingName': '1동',
#   'roomTypeId': 37011,
#   'grossAreaName': {'m2': 129, 'p': 39},
#   'grossArea': {'m2': 129, 'p': 39},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 99, 'p': 29},
#   'floorPlan': 'http://s.zigbang.com/v2/web/danji/area_empty.jpg',
#   'userNo': 2750231,
#   'agentId': 2750231,
#   'agentName': '디엠씨엘가부동산공인중개사',
#   'agentTel': '0226423366',
#   'agentUserName': '홍윤지',
#   'agentPhone': '01033294336',
#   'created_at': '2019-09-17 11:22:29',
#   'real_type': '아파트',
#   'itemImage': ['http://s.zigbang.com/v2/web/danji/area_empty.jpg'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 129, 'p': 39},
#   'isNew': True,
#   'sales': 52000},
#  {'itemId': 18032754,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '19',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.56949108361799,
#   'lng': 126.91721400143786,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '수리. 채광좋음',
#   'agentNo': 32647,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T08:03:49.000Z',
#   'apartmentId': 7753,
#   'apartmentName': '창덕에버빌',
#   'buildingName': '1동',
#   'roomTypeId': 37011,
#   'grossAreaName': {'m2': 129, 'p': 39},
#   'grossArea': {'m2': 129, 'p': 39},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 99, 'p': 29},
#   'floorPlan': 'http://s.zigbang.com/v2/web/danji/area_empty.jpg',
#   'userNo': 2750231,
#   'agentId': 2750231,
#   'agentName': '디엠씨엘가부동산공인중개사',
#   'agentTel': '0226423366',
#   'agentUserName': '홍윤지',
#   'agentPhone': '01033294336',
#   'created_at': '2019-09-17 11:40:33',
#   'real_type': '아파트',
#   'itemImage': ['http://s.zigbang.com/v2/web/danji/area_empty.jpg'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 129, 'p': 39},
#   'isNew': True,
#   'sales': 53000},
#  {'itemId': 18031699,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.572898864746094,
#   'lng': 126.91799926757812,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '전세끼고 매수가능.입구동.교통편리. ',
#   'agentNo': 32647,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T08:03:49.000Z',
#   'apartmentId': 33297,
#   'apartmentName': 'DMC파크뷰자이1단지',
#   'buildingName': '123동',
#   'roomTypeId': 91745,
#   'grossAreaName': {'m2': '111F', 'p': '33F'},
#   'grossArea': {'m2': 111, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33297/91745/dffd858f8fe1438f944a6ff4b57aea5b.png',
#   'userNo': 2750231,
#   'agentId': 2750231,
#   'agentName': '디엠씨엘가부동산공인중개사',
#   'agentTel': '0226423366',
#   'agentUserName': '홍윤지',
#   'agentPhone': '01033294336',
#   'created_at': '2019-09-17 11:14:58',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33297/91745/dffd858f8fe1438f944a6ff4b57aea5b.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '111F', 'p': '33F'},
#   'isNew': True,
#   'sales': 105000},
#  {'itemId': 18031846,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '31',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.572898864746094,
#   'lng': 126.91799926757812,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '넓은평수 . 공간분리가 잘되어 있어 2세대가 살기 편함',
#   'agentNo': 32647,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T08:03:49.000Z',
#   'apartmentId': 33297,
#   'apartmentName': 'DMC파크뷰자이1단지',
#   'buildingName': '126동',
#   'roomTypeId': 91751,
#   'grossAreaName': {'m2': 208, 'p': 62},
#   'grossArea': {'m2': 208, 'p': 62},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 175, 'p': 52},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33297/91751/d3b562f90364436e808f97245eea5207.png',
#   'userNo': 2750231,
#   'agentId': 2750231,
#   'agentName': '디엠씨엘가부동산공인중개사',
#   'agentTel': '0226423366',
#   'agentUserName': '홍윤지',
#   'agentPhone': '01033294336',
#   'created_at': '2019-09-17 11:18:18',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33297/91751/d3b562f90364436e808f97245eea5207.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 208, 'p': 62},
#   'isNew': True,
#   'sales': 170000},
#  {'itemId': 18302600,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '21',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.572898864746094,
#   'lng': 126.91799926757812,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '거실뷰가 좋고 채광이 좋아서 하루종일 밝음',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T08:03:48.000Z',
#   'apartmentId': 33297,
#   'apartmentName': 'DMC파크뷰자이1단지',
#   'buildingName': '127동',
#   'roomTypeId': 91744,
#   'grossAreaName': {'m2': '111E', 'p': '33E'},
#   'grossArea': {'m2': 111, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33297/91744/87a6f78856434cff9a702e8d4c2bc193.png',
#   'userNo': 2750231,
#   'agentId': 2750231,
#   'agentName': '디엠씨엘가부동산공인중개사',
#   'agentTel': '0226423366',
#   'agentUserName': '홍윤지',
#   'agentPhone': '01033294336',
#   'created_at': '2019-10-04 16:50:32',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33297/91744/87a6f78856434cff9a702e8d4c2bc193.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '111E', 'p': '33E'},
#   'isNew': True,
#   'sales': 100000},
#  {'itemId': 18313570,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '32',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.572898864746094,
#   'lng': 126.91799926757812,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '특 A급. 에어컨 3대',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T08:03:48.000Z',
#   'apartmentId': 33297,
#   'apartmentName': 'DMC파크뷰자이1단지',
#   'buildingName': '118동',
#   'roomTypeId': 91749,
#   'grossAreaName': {'m2': 157, 'p': 47},
#   'grossArea': {'m2': 157, 'p': 47},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 121, 'p': 36},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33297/91749/a55224a805724a8da55557393f44bd2c.png',
#   'userNo': 2750231,
#   'agentId': 2750231,
#   'agentName': '디엠씨엘가부동산공인중개사',
#   'agentTel': '0226423366',
#   'agentUserName': '홍윤지',
#   'agentPhone': '01033294336',
#   'created_at': '2019-10-05 14:09:30',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33297/91749/a55224a805724a8da55557393f44bd2c.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 157, 'p': 47},
#   'isNew': True,
#   'sales': 135000},
#  {'itemId': 18833956,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '18',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.56204970592121,
#   'lng': 126.95102783170678,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '같은평수 착한가격,  로얄동, 방3, 화장실1',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T08:02:30.000Z',
#   'apartmentId': 50235,
#   'apartmentName': '힐스테이트신촌',
#   'buildingName': '103동',
#   'roomTypeId': 236976,
#   'grossAreaName': {'m2': 78, 'p': 23},
#   'grossArea': {'m2': 78, 'p': 23},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 55, 'p': 16},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/50235/236976/206918d787654552b2db3fd30eaec8c3.png',
#   'userNo': 7098909,
#   'agentId': 7098909,
#   'agentName': '키움(단지내)공인중개사사무소',
#   'agentTel': '023934400',
#   'agentUserName': '이미정',
#   'agentPhone': '01052322163',
#   'created_at': '2019-11-09 13:04:19',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/50235/236976/206918d787654552b2db3fd30eaec8c3.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 78, 'p': 23},
#   'isNew': True,
#   'sales': 92000},
#  {'itemId': 18832385,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '19',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5499044146751,
#   'lng': 126.95140243355593,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '해잘드는집. 공덕역세권 로얄동. 추천매물.',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:57:12.000Z',
#   'apartmentId': 9514,
#   'apartmentName': '공덕래미안4차',
#   'buildingName': '412동',
#   'roomTypeId': 11815,
#   'grossAreaName': {'m2': 84, 'p': 25},
#   'grossArea': {'m2': 84, 'p': 25},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/9514/11815/51504ba45d804d0da6f2474e9097787f.png',
#   'userNo': 4913573,
#   'agentId': 4913573,
#   'agentName': '서울래미안공인중개사',
#   'agentTel': '027118924',
#   'agentUserName': '김태숙',
#   'agentPhone': '01089233384',
#   'created_at': '2019-11-09 11:42:22',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/9514/11815/51504ba45d804d0da6f2474e9097787f.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 84, 'p': 25},
#   'isNew': True,
#   'sales': 102000},
#  {'itemId': 18831476,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '22',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5554063,
#   'lng': 126.944267,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '명품자이 편의시설 최고 초역세권',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:45:17.000Z',
#   'apartmentId': 37974,
#   'apartmentName': '신촌그랑자이',
#   'buildingName': '110동',
#   'roomTypeId': 158483,
#   'grossAreaName': {'m2': '82B', 'p': '24B'},
#   'grossArea': {'m2': 82, 'p': 24},
#   'agreementArea': {'m2': 122, 'p': 36},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/37974/158483/7aed3aa49970476496adb6d638e1cdda.png',
#   'userNo': 4084902,
#   'agentId': 4084902,
#   'agentName': '부자공인중개사사무소',
#   'agentTel': '027015555',
#   'agentUserName': '김의태',
#   'agentPhone': '01091234237',
#   'created_at': '2019-11-09 11:12:19',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/37974/158483/7aed3aa49970476496adb6d638e1cdda.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '82B', 'p': '24B'},
#   'isNew': True,
#   'sales': 150000},
#  {'itemId': 18831595,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '22',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5554063,
#   'lng': 126.944267,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '명품자이 귀한매매 확실한매물입니다',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:45:11.000Z',
#   'apartmentId': 37974,
#   'apartmentName': '신촌그랑자이',
#   'buildingName': '110동',
#   'roomTypeId': 158482,
#   'grossAreaName': {'m2': '80A', 'p': '24A'},
#   'grossArea': {'m2': 80, 'p': 24},
#   'agreementArea': {'m2': 120, 'p': 36},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/37974/158482/2ef715717f3b457a8dfa069a809a8be6.png',
#   'userNo': 4084902,
#   'agentId': 4084902,
#   'agentName': '부자공인중개사사무소',
#   'agentTel': '027015555',
#   'agentUserName': '김의태',
#   'agentPhone': '01091234237',
#   'created_at': '2019-11-09 11:15:59',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/37974/158482/2ef715717f3b457a8dfa069a809a8be6.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '80A', 'p': '24A'},
#   'isNew': True,
#   'sales': 150000},
#  {'itemId': 18835905,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.56204970592121,
#   'lng': 126.95102783170678,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '조망 일조권 최고',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:42:51.000Z',
#   'apartmentId': 50235,
#   'apartmentName': '힐스테이트신촌',
#   'buildingName': '105동',
#   'roomTypeId': 165690,
#   'grossAreaName': {'m2': '114E', 'p': '34E'},
#   'grossArea': {'m2': 114, 'p': 34},
#   'agreementArea': {'m2': 179, 'p': 54},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/50235/165690/c5076a20ab48420982966646c92ac632.png',
#   'userNo': 6119760,
#   'agentId': 6119760,
#   'agentName': '한국부동산중개사무소',
#   'agentTel': '023938982',
#   'agentUserName': '오재근',
#   'agentPhone': '01090078544',
#   'created_at': '2019-11-09 14:58:23',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/50235/165690/c5076a20ab48420982966646c92ac632.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '114E', 'p': '34E'},
#   'isNew': True,
#   'sales': 130000},
#  {'itemId': 18833931,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '16',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.53942497854966,
#   'lng': 126.95386230877646,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '공덕역세권, 입주협의, 상태깨끗',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:42:34.000Z',
#   'apartmentId': 2973,
#   'apartmentName': '도화현대1차',
#   'buildingName': '104동',
#   'roomTypeId': 147216,
#   'grossAreaName': {'m2': 94, 'p': 28},
#   'grossArea': {'m2': 94, 'p': 28},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 68, 'p': 20},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/2973/147216/b6db8705053140938089281a2ff7d71c.png',
#   'userNo': 6113973,
#   'agentId': 6113973,
#   'agentName': '이화공인중개사사무소',
#   'agentTel': '027014433',
#   'agentUserName': '신승열',
#   'agentPhone': '01087246479',
#   'created_at': '2019-11-09 13:02:48',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/2973/147216/b6db8705053140938089281a2ff7d71c.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 94, 'p': 28},
#   'isNew': True,
#   'sales': 82000},
#  {'itemId': 17793963,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '23',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54319539618407,
#   'lng': 126.95551657202964,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '입구동,작은방확장,부분수리,입주가능해요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:55.000Z',
#   'apartmentId': 3726,
#   'apartmentName': '신공덕삼성래미안1차',
#   'buildingName': '103동',
#   'roomTypeId': 6609,
#   'grossAreaName': {'m2': 142, 'p': 42},
#   'grossArea': {'m2': 142, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3726/6609/d82aec32dc1c46e4a560a50df54d1eb9.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-08-28 14:57:13',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3726/6609/d82aec32dc1c46e4a560a50df54d1eb9.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 142, 'p': 42},
#   'isNew': True,
#   'sales': 137000},
#  {'itemId': 17836660,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '21',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54319539618407,
#   'lng': 126.95551657202964,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,올수리,확장형,채광최고,입주가능해요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:55.000Z',
#   'apartmentId': 3726,
#   'apartmentName': '신공덕삼성래미안1차',
#   'buildingName': '107동',
#   'roomTypeId': 6609,
#   'grossAreaName': {'m2': 142, 'p': 42},
#   'grossArea': {'m2': 142, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3726/6609/d82aec32dc1c46e4a560a50df54d1eb9.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-08-31 11:38:58',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3726/6609/d82aec32dc1c46e4a560a50df54d1eb9.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 142, 'p': 42},
#   'isNew': True,
#   'sales': 132000},
#  {'itemId': 18404687,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '21',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54319539618407,
#   'lng': 126.95551657202964,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '조용한동,채광좋고,수리한집,입주가능해요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:55.000Z',
#   'apartmentId': 3726,
#   'apartmentName': '신공덕삼성래미안1차',
#   'buildingName': '108동',
#   'roomTypeId': 6610,
#   'grossAreaName': {'m2': 81, 'p': 24},
#   'grossArea': {'m2': 81, 'p': 24},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3726/6610/1b3fd064873f472ab42b6a9bc0834c61.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-11 17:51:05',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3726/6610/1b3fd064873f472ab42b6a9bc0834c61.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 81, 'p': 24},
#   'isNew': True,
#   'sales': 94000},
#  {'itemId': 18404711,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '21',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54319539618407,
#   'lng': 126.95551657202964,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,채광최고,깨끗,입주가능해요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:55.000Z',
#   'apartmentId': 3726,
#   'apartmentName': '신공덕삼성래미안1차',
#   'buildingName': '107동',
#   'roomTypeId': 6608,
#   'grossAreaName': {'m2': 109, 'p': 32},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3726/6608/9747c5a0a6084eb885b4eb77fd327b9f.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-11 17:52:00',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3726/6608/9747c5a0a6084eb885b4eb77fd327b9f.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 109, 'p': 32},
#   'isNew': True,
#   'sales': 115000},
#  {'itemId': 18305793,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54547723784517,
#   'lng': 126.9568957471628,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,채광 최고,지하 주차장과 연결됨,입주매매.',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:55.000Z',
#   'apartmentId': 6343,
#   'apartmentName': '신공덕삼성래미안3차',
#   'buildingName': '303동',
#   'roomTypeId': 10343,
#   'grossAreaName': {'m2': 79, 'p': 23},
#   'grossArea': {'m2': 79, 'p': 23},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/6343/10343/d565c98455da4556bfd165322a3cf375.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-04 18:50:43',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/6343/10343/d565c98455da4556bfd165322a3cf375.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 79, 'p': 23},
#   'isNew': True,
#   'sales': 95000},
#  {'itemId': 18404589,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '19',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54547723784517,
#   'lng': 126.9568957471628,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,올수리,조망.채광최고,지하주차장연결,전세안고 매매에요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:55.000Z',
#   'apartmentId': 6343,
#   'apartmentName': '신공덕삼성래미안3차',
#   'buildingName': '302동',
#   'roomTypeId': 10342,
#   'grossAreaName': {'m2': 139, 'p': 42},
#   'grossArea': {'m2': 139, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/6343/10342/7726c331179942c082640a7e79ce3133.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-11 17:47:25',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/6343/10342/7726c331179942c082640a7e79ce3133.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 139, 'p': 42},
#   'isNew': True,
#   'sales': 117000},
#  {'itemId': 18404616,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '18',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54547723784517,
#   'lng': 126.9568957471628,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,전체특올수리,올확장,전세안고 매매에요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:55.000Z',
#   'apartmentId': 6343,
#   'apartmentName': '신공덕삼성래미안3차',
#   'buildingName': '304동',
#   'roomTypeId': 10342,
#   'grossAreaName': {'m2': 139, 'p': 42},
#   'grossArea': {'m2': 139, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/6343/10342/7726c331179942c082640a7e79ce3133.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-11 17:48:32',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/6343/10342/7726c331179942c082640a7e79ce3133.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 139, 'p': 42},
#   'isNew': True,
#   'sales': 108000},
#  {'itemId': 18524522,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '11',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54194539356191,
#   'lng': 126.957096929717,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,올수리한집,채광최고,입주가능해요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:55.000Z',
#   'apartmentId': 15221,
#   'apartmentName': '신공덕e편한세상',
#   'buildingName': '101동',
#   'roomTypeId': 47541,
#   'grossAreaName': {'m2': 105, 'p': 31},
#   'grossArea': {'m2': 105, 'p': 31},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/15221/47541/18b0b8feccc24c3cacd7a1d0fde5a22d.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-21 11:05:11',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/15221/47541/18b0b8feccc24c3cacd7a1d0fde5a22d.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 105, 'p': 31},
#   'isNew': True,
#   'sales': 110000},
#  {'itemId': 18524601,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '11',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54194539356191,
#   'lng': 126.957096929717,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,채광최고,입주가능해요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:55.000Z',
#   'apartmentId': 15221,
#   'apartmentName': '신공덕e편한세상',
#   'buildingName': '101동',
#   'roomTypeId': 47541,
#   'grossAreaName': {'m2': 105, 'p': 31},
#   'grossArea': {'m2': 105, 'p': 31},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/15221/47541/18b0b8feccc24c3cacd7a1d0fde5a22d.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-21 11:07:22',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/15221/47541/18b0b8feccc24c3cacd7a1d0fde5a22d.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 105, 'p': 31},
#   'isNew': True,
#   'sales': 115000},
#  {'itemId': 18524655,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '13',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54194539356191,
#   'lng': 126.957096929717,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,전체특올수리,채광최고,입주가능해요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:55.000Z',
#   'apartmentId': 15221,
#   'apartmentName': '신공덕e편한세상',
#   'buildingName': '103동',
#   'roomTypeId': 47538,
#   'grossAreaName': {'m2': 81, 'p': 24},
#   'grossArea': {'m2': 81, 'p': 24},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/15221/47538/8eadfc53e36c42d68d9570ec495533af.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-21 11:09:11',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/15221/47538/8eadfc53e36c42d68d9570ec495533af.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 81, 'p': 24},
#   'isNew': True,
#   'sales': 93000},
#  {'itemId': 18039746,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54151225073908,
#   'lng': 126.95530937183123,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,올확장,올수리,최상깨끗,입주가능해요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:55.000Z',
#   'apartmentId': 17630,
#   'apartmentName': '공덕브라운스톤',
#   'buildingName': '103동',
#   'roomTypeId': 14563,
#   'grossAreaName': {'m2': 107, 'p': 32},
#   'grossArea': {'m2': 107, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/17630/14563/76b21a1b050640f7b29b918d4ba14bd4.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-09-17 15:47:36',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/17630/14563/76b21a1b050640f7b29b918d4ba14bd4.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 107, 'p': 32},
#   'isNew': True,
#   'sales': 140000},
#  {'itemId': 18306286,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54151225073908,
#   'lng': 126.95530937183123,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,채광최고,올확장,입주 가능해요.',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:55.000Z',
#   'apartmentId': 17630,
#   'apartmentName': '공덕브라운스톤',
#   'buildingName': '101동',
#   'roomTypeId': 14565,
#   'grossAreaName': {'m2': 81, 'p': 24},
#   'grossArea': {'m2': 81, 'p': 24},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/17630/14565/93bee89b90e6456bb055a59bb0ecfa30.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-04 19:16:42',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/17630/14565/93bee89b90e6456bb055a59bb0ecfa30.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 81, 'p': 24},
#   'isNew': True,
#   'sales': 115000},
#  {'itemId': 18353152,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54151225073908,
#   'lng': 126.95530937183123,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,방3개 구조,상태 깨끗,전세안고 매매.',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:55.000Z',
#   'apartmentId': 17630,
#   'apartmentName': '공덕브라운스톤',
#   'buildingName': '103동',
#   'roomTypeId': 14565,
#   'grossAreaName': {'m2': 81, 'p': 24},
#   'grossArea': {'m2': 81, 'p': 24},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/17630/14565/93bee89b90e6456bb055a59bb0ecfa30.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-08 15:49:20',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/17630/14565/93bee89b90e6456bb055a59bb0ecfa30.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 81, 'p': 24},
#   'isNew': True,
#   'sales': 107000},
#  {'itemId': 18525782,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '21',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54319539618407,
#   'lng': 126.95551657202964,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '전체특올수리,남산.효창공원조망최고,입주가능해요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:54.000Z',
#   'apartmentId': 3726,
#   'apartmentName': '신공덕삼성래미안1차',
#   'buildingName': '109동',
#   'roomTypeId': 6609,
#   'grossAreaName': {'m2': 142, 'p': 42},
#   'grossArea': {'m2': 142, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3726/6609/d82aec32dc1c46e4a560a50df54d1eb9.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-21 11:37:10',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3726/6609/d82aec32dc1c46e4a560a50df54d1eb9.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 142, 'p': 42},
#   'isNew': True,
#   'sales': 145000},
#  {'itemId': 18578502,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '23',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54319539618407,
#   'lng': 126.95551657202964,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '샷시까지특올수리,입구동,최상깨끗,입주가능해요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:54.000Z',
#   'apartmentId': 3726,
#   'apartmentName': '신공덕삼성래미안1차',
#   'buildingName': '103동',
#   'roomTypeId': 6609,
#   'grossAreaName': {'m2': 142, 'p': 42},
#   'grossArea': {'m2': 142, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3726/6609/d82aec32dc1c46e4a560a50df54d1eb9.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-24 11:01:52',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3726/6609/d82aec32dc1c46e4a560a50df54d1eb9.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 142, 'p': 42},
#   'isNew': True,
#   'sales': 142000},
#  {'itemId': 18601647,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '22',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54319539618407,
#   'lng': 126.95551657202964,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,샷시까지올수리,채광최고,입주가능해요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:54.000Z',
#   'apartmentId': 3726,
#   'apartmentName': '신공덕삼성래미안1차',
#   'buildingName': '102동',
#   'roomTypeId': 6608,
#   'grossAreaName': {'m2': 109, 'p': 32},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3726/6608/9747c5a0a6084eb885b4eb77fd327b9f.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-25 14:38:34',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3726/6608/9747c5a0a6084eb885b4eb77fd327b9f.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 109, 'p': 32},
#   'isNew': True,
#   'sales': 120000},
#  {'itemId': 18680174,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '22',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54319539618407,
#   'lng': 126.95551657202964,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,입구동,조망.채광최고,입주가능해요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:54.000Z',
#   'apartmentId': 3726,
#   'apartmentName': '신공덕삼성래미안1차',
#   'buildingName': '104동',
#   'roomTypeId': 6610,
#   'grossAreaName': {'m2': 81, 'p': 24},
#   'grossArea': {'m2': 81, 'p': 24},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3726/6610/1b3fd064873f472ab42b6a9bc0834c61.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-31 10:25:49',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3726/6610/1b3fd064873f472ab42b6a9bc0834c61.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 81, 'p': 24},
#   'isNew': True,
#   'sales': 100000},
#  {'itemId': 18736122,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '22',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54319539618407,
#   'lng': 126.95551657202964,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '채광좋고,깨끗,전세안고 매매에요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:54.000Z',
#   'apartmentId': 3726,
#   'apartmentName': '신공덕삼성래미안1차',
#   'buildingName': '101동',
#   'roomTypeId': 6609,
#   'grossAreaName': {'m2': 142, 'p': 42},
#   'grossArea': {'m2': 142, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3726/6609/d82aec32dc1c46e4a560a50df54d1eb9.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-11-04 10:24:39',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3726/6609/d82aec32dc1c46e4a560a50df54d1eb9.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 142, 'p': 42},
#   'isNew': True,
#   'sales': 131000},
#  {'itemId': 18726134,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '22',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54547723784517,
#   'lng': 126.9568957471628,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '출입이 편한 입구동,기본형 구조,상태 깨끗해요.',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:54.000Z',
#   'apartmentId': 6343,
#   'apartmentName': '신공덕삼성래미안3차',
#   'buildingName': '301동',
#   'roomTypeId': 10343,
#   'grossAreaName': {'m2': 79, 'p': 23},
#   'grossArea': {'m2': 79, 'p': 23},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/6343/10343/d565c98455da4556bfd165322a3cf375.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-11-02 15:43:12',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/6343/10343/d565c98455da4556bfd165322a3cf375.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 79, 'p': 23},
#   'isNew': True,
#   'sales': 90000},
#  {'itemId': 18524696,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '13',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54194539356191,
#   'lng': 126.957096929717,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '지하주차장연결,올확장,전세안고 매매에요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:54.000Z',
#   'apartmentId': 15221,
#   'apartmentName': '신공덕e편한세상',
#   'buildingName': '103동',
#   'roomTypeId': 47539,
#   'grossAreaName': {'m2': '82A', 'p': '24A'},
#   'grossArea': {'m2': 82, 'p': 24},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/15221/47539/24aa8eb3901c42438b398a93ebd01086.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-21 11:10:19',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/15221/47539/24aa8eb3901c42438b398a93ebd01086.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': '82A', 'p': '24A'},
#   'isNew': True,
#   'sales': 95000},
#  {'itemId': 18524779,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '13',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54194539356191,
#   'lng': 126.957096929717,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,올확장,채광최고,전세안고 매매에요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:54.000Z',
#   'apartmentId': 15221,
#   'apartmentName': '신공덕e편한세상',
#   'buildingName': '103동',
#   'roomTypeId': 47538,
#   'grossAreaName': {'m2': 81, 'p': 24},
#   'grossArea': {'m2': 81, 'p': 24},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/15221/47538/8eadfc53e36c42d68d9570ec495533af.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-21 11:12:20',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/15221/47538/8eadfc53e36c42d68d9570ec495533af.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 81, 'p': 24},
#   'isNew': True,
#   'sales': 91000},
#  {'itemId': 18544071,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54151225073908,
#   'lng': 126.95530937183123,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,올확장,채광최고,전세안고 매매에요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:27:54.000Z',
#   'apartmentId': 17630,
#   'apartmentName': '공덕브라운스톤',
#   'buildingName': '101동',
#   'roomTypeId': 14565,
#   'grossAreaName': {'m2': 81, 'p': 24},
#   'grossArea': {'m2': 81, 'p': 24},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/17630/14565/93bee89b90e6456bb055a59bb0ecfa30.png',
#   'userNo': 5304024,
#   'agentId': 5304024,
#   'agentName': '으뜸공인중개사사무소',
#   'agentTel': '027178686',
#   'agentUserName': '지수옥',
#   'agentPhone': '01091545417',
#   'created_at': '2019-10-22 11:19:37',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/17630/14565/93bee89b90e6456bb055a59bb0ecfa30.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 81, 'p': 24},
#   'isNew': True,
#   'sales': 112000},
#  {'itemId': 18364834,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '19',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55379288404938,
#   'lng': 126.92369568722684,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '홍대역세권 초저렴한 아파트  전세 안고 매수 가능합니다.',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:17:27.000Z',
#   'apartmentId': 10030,
#   'apartmentName': '서교푸르지오',
#   'buildingName': '101동',
#   'roomTypeId': 42272,
#   'grossAreaName': {'m2': 115, 'p': 34},
#   'grossArea': {'m2': 115, 'p': 34},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 92, 'p': 27},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/10030/42272/a7f12afa2aad412a845af2c945b541ca.png',
#   'userNo': 2199459,
#   'agentId': 2199459,
#   'agentName': '나눔공인중개사사무소',
#   'agentTel': '023230771',
#   'agentUserName': '곽숙경',
#   'agentPhone': '01052659570',
#   'created_at': '2019-10-09 13:12:49',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/10030/42272/a7f12afa2aad412a845af2c945b541ca.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 115, 'p': 34},
#   'isNew': True,
#   'sales': 85000},
#  {'itemId': 18364858,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '19',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55379288404938,
#   'lng': 126.92369568722684,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '리모델링한 정원있는   초역세권 쾌적한아파트',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:17:27.000Z',
#   'apartmentId': 10030,
#   'apartmentName': '서교푸르지오',
#   'buildingName': '101동',
#   'roomTypeId': 42272,
#   'grossAreaName': {'m2': 115, 'p': 34},
#   'grossArea': {'m2': 115, 'p': 34},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 92, 'p': 27},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/10030/42272/a7f12afa2aad412a845af2c945b541ca.png',
#   'userNo': 2199459,
#   'agentId': 2199459,
#   'agentName': '나눔공인중개사사무소',
#   'agentTel': '023230771',
#   'agentUserName': '곽숙경',
#   'agentPhone': '01052659570',
#   'created_at': '2019-10-09 13:14:05',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/10030/42272/a7f12afa2aad412a845af2c945b541ca.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 115, 'p': 34},
#   'isNew': True,
#   'sales': 92000},
#  {'itemId': 18364821,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '12',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55737058374525,
#   'lng': 126.9167882886154,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '실입주 가능한 저렴한 아파트',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T07:17:27.000Z',
#   'apartmentId': 10252,
#   'apartmentName': '서교대우미래사랑',
#   'buildingName': '1동',
#   'roomTypeId': 166266,
#   'grossAreaName': {'m2': 112, 'p': 33},
#   'grossArea': {'m2': 112, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/10252/166266/f495eec382c1471fad688563e2ecf4ad.png',
#   'userNo': 2199459,
#   'agentId': 2199459,
#   'agentName': '나눔공인중개사사무소',
# ...
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '111F', 'p': '33F'},
#   'isNew': True,
#   'sales': 115000},
#  {'itemId': 18193013,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '32',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.572898864746094,
#   'lng': 126.91799926757812,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '확장형 시스템에어컨 조경뷰 전망시원 ',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T01:39:22.000Z',
#   'apartmentId': 33297,
#   'apartmentName': 'DMC파크뷰자이1단지',
#   'buildingName': '118동',
#   'roomTypeId': 91749,
#   'grossAreaName': {'m2': 157, 'p': 47},
#   'grossArea': {'m2': 157, 'p': 47},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 121, 'p': 36},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33297/91749/a55224a805724a8da55557393f44bd2c.png',
#   'userNo': 2769725,
#   'agentId': 2769725,
#   'agentName': '단지내(가재울)공인중개사',
#   'agentTel': '023747700',
#   'agentUserName': '하경학',
#   'agentPhone': '01022505500',
#   'created_at': '2019-09-27 12:07:37',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33297/91749/a55224a805724a8da55557393f44bd2c.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 157, 'p': 47},
#   'isNew': True,
#   'sales': 135000},
#  {'itemId': 18434311,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '29',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.572898864746094,
#   'lng': 126.91799926757812,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '확장형 시스템에어컨 전망굿 선호동',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T01:39:22.000Z',
#   'apartmentId': 33297,
#   'apartmentName': 'DMC파크뷰자이1단지',
#   'buildingName': '115동',
#   'roomTypeId': 91745,
#   'grossAreaName': {'m2': '111F', 'p': '33F'},
#   'grossArea': {'m2': 111, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33297/91745/dffd858f8fe1438f944a6ff4b57aea5b.png',
#   'userNo': 2769725,
#   'agentId': 2769725,
#   'agentName': '단지내(가재울)공인중개사',
#   'agentTel': '023747700',
#   'agentUserName': '하경학',
#   'agentPhone': '01022505500',
#   'created_at': '2019-10-14 15:42:21',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33297/91745/dffd858f8fe1438f944a6ff4b57aea5b.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '111F', 'p': '33F'},
#   'isNew': True,
#   'sales': 110000},
#  {'itemId': 18827863,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '22',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5532387,
#   'lng': 126.953,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '전망트이고 내부깔끔해요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T01:29:13.000Z',
#   'apartmentId': 23195,
#   'apartmentName': '마포래미안푸르지오',
#   'buildingName': '104동',
#   'roomTypeId': 19342,
#   'grossAreaName': {'m2': '80B', 'p': '24B'},
#   'grossArea': {'m2': 80, 'p': 24},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/23195/19342/3dafc31fc08043e690e3406b205fe3eb.png',
#   'userNo': 1350579,
#   'agentId': 1350579,
#   'agentName': '애오개공인중개사',
#   'agentTel': '023638990',
#   'agentUserName': '황명숙',
#   'agentPhone': '01029773234',
#   'created_at': '2019-11-08 18:56:37',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/23195/19342/3dafc31fc08043e690e3406b205fe3eb.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': '80B', 'p': '24B'},
#   'isNew': True,
#   'sales': 145000},
#  {'itemId': 17821463,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '22',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54473232045174,
#   'lng': 126.94257048117984,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '반전세 승계조건, 3억/30만원',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T00:59:48.000Z',
#   'apartmentId': 2952,
#   'apartmentName': '대흥태영',
#   'buildingName': '104동',
#   'roomTypeId': 6353,
#   'grossAreaName': {'m2': 83, 'p': 25},
#   'grossArea': {'m2': 83, 'p': 25},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/2952/6353/1e62e6ed53cb4b2284ecf7b9280d3970.png',
#   'userNo': 2622344,
#   'agentId': 2622344,
#   'agentName': 'e편한중앙공인중개사',
#   'agentTel': '02-6732-4989',
#   'agentUserName': '김수연',
#   'agentPhone': '01066770024',
#   'created_at': '2019-08-30 10:56:52',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/2952/6353/1e62e6ed53cb4b2284ecf7b9280d3970.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 83, 'p': 25},
#   'isNew': True,
#   'sales': 84000},
#  {'itemId': 18280441,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '22',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54473232045174,
#   'lng': 126.94257048117984,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '전세 4억 끼고 내집 장만, 급매매 투자굿',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T00:59:48.000Z',
#   'apartmentId': 2952,
#   'apartmentName': '대흥태영',
#   'buildingName': '104동',
#   'roomTypeId': 6353,
#   'grossAreaName': {'m2': 83, 'p': 25},
#   'grossArea': {'m2': 83, 'p': 25},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/2952/6353/1e62e6ed53cb4b2284ecf7b9280d3970.png',
#   'userNo': 2622344,
#   'agentId': 2622344,
#   'agentName': 'e편한중앙공인중개사',
#   'agentTel': '02-6732-4989',
#   'agentUserName': '김수연',
#   'agentPhone': '01066770024',
#   'created_at': '2019-10-03 12:01:14',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/2952/6353/1e62e6ed53cb4b2284ecf7b9280d3970.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 83, 'p': 25},
#   'isNew': True,
#   'sales': 81500},
#  {'itemId': 18280487,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54473232045174,
#   'lng': 126.94257048117984,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '올수리 확장, 신혼부부 추천, ',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T00:59:48.000Z',
#   'apartmentId': 2952,
#   'apartmentName': '대흥태영',
#   'buildingName': '106동',
#   'roomTypeId': 6353,
#   'grossAreaName': {'m2': 83, 'p': 25},
#   'grossArea': {'m2': 83, 'p': 25},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/2952/6353/1e62e6ed53cb4b2284ecf7b9280d3970.png',
#   'userNo': 2622344,
#   'agentId': 2622344,
#   'agentName': 'e편한중앙공인중개사',
#   'agentTel': '02-6732-4989',
#   'agentUserName': '김수연',
#   'agentPhone': '01066770024',
#   'created_at': '2019-10-03 12:03:06',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/2952/6353/1e62e6ed53cb4b2284ecf7b9280d3970.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 83, 'p': 25},
#   'isNew': True,
#   'sales': 85000},
#  {'itemId': 18710302,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '24',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54473232045174,
#   'lng': 126.94257048117984,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '염리초배정, 200세대 대단지 아파트 , 지하주차장 연결',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T00:59:48.000Z',
#   'apartmentId': 2952,
#   'apartmentName': '대흥태영',
#   'buildingName': '107동',
#   'roomTypeId': 6352,
#   'grossAreaName': {'m2': 142, 'p': 42},
#   'grossArea': {'m2': 142, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/2952/6352/80981e4304f94663b1d49d7b27cf98e6.png',
#   'userNo': 2622344,
#   'agentId': 2622344,
#   'agentName': 'e편한중앙공인중개사',
#   'agentTel': '02-6732-4989',
#   'agentUserName': '김수연',
#   'agentPhone': '01066770024',
#   'created_at': '2019-11-01 15:54:53',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/2952/6352/80981e4304f94663b1d49d7b27cf98e6.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 142, 'p': 42},
#   'isNew': True,
#   'sales': 122000},
#  {'itemId': 18710347,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '18',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54473232045174,
#   'lng': 126.94257048117984,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '내부 깔끔, 염리초 배정',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T00:59:48.000Z',
#   'apartmentId': 2952,
#   'apartmentName': '대흥태영',
#   'buildingName': '113동',
#   'roomTypeId': 6352,
#   'grossAreaName': {'m2': 142, 'p': 42},
#   'grossArea': {'m2': 142, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/2952/6352/80981e4304f94663b1d49d7b27cf98e6.png',
#   'userNo': 2622344,
#   'agentId': 2622344,
#   'agentName': 'e편한중앙공인중개사',
#   'agentTel': '02-6732-4989',
#   'agentUserName': '김수연',
#   'agentPhone': '01066770024',
#   'created_at': '2019-11-01 15:56:03',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/2952/6352/80981e4304f94663b1d49d7b27cf98e6.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 142, 'p': 42},
#   'isNew': True,
#   'sales': 123000},
#  {'itemId': 18710419,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54473232045174,
#   'lng': 126.94257048117984,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '수리 되었어요,  염리초 배정받아요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T00:59:48.000Z',
#   'apartmentId': 2952,
#   'apartmentName': '대흥태영',
#   'buildingName': '102동',
#   'roomTypeId': 6351,
#   'grossAreaName': {'m2': 109, 'p': 32},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/2952/6351/07cb1a3b07f04790819823f0777f6024.png',
#   'userNo': 2622344,
#   'agentId': 2622344,
#   'agentName': 'e편한중앙공인중개사',
#   'agentTel': '02-6732-4989',
#   'agentUserName': '김수연',
#   'agentPhone': '01066770024',
#   'created_at': '2019-11-01 15:57:55',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/2952/6351/07cb1a3b07f04790819823f0777f6024.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 109, 'p': 32},
#   'isNew': True,
#   'sales': 107000},
#  {'itemId': 18710499,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54473232045174,
#   'lng': 126.94257048117984,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '1층 , 아랫층 층간소음 걱정 없어요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T00:59:48.000Z',
#   'apartmentId': 2952,
#   'apartmentName': '대흥태영',
#   'buildingName': '106동',
#   'roomTypeId': 6353,
#   'grossAreaName': {'m2': 83, 'p': 25},
#   'grossArea': {'m2': 83, 'p': 25},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/2952/6353/1e62e6ed53cb4b2284ecf7b9280d3970.png',
#   'userNo': 2622344,
#   'agentId': 2622344,
#   'agentName': 'e편한중앙공인중개사',
#   'agentTel': '02-6732-4989',
#   'agentUserName': '김수연',
#   'agentPhone': '01066770024',
#   'created_at': '2019-11-01 16:00:00',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/2952/6353/1e62e6ed53cb4b2284ecf7b9280d3970.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 83, 'p': 25},
#   'isNew': True,
#   'sales': 78000},
#  {'itemId': 18711754,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '22',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54473232045174,
#   'lng': 126.94257048117984,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '내부 수리상태 양호 깨끗해요',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T00:59:48.000Z',
#   'apartmentId': 2952,
#   'apartmentName': '대흥태영',
#   'buildingName': '104동',
#   'roomTypeId': 6353,
#   'grossAreaName': {'m2': 83, 'p': 25},
#   'grossArea': {'m2': 83, 'p': 25},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/2952/6353/1e62e6ed53cb4b2284ecf7b9280d3970.png',
#   'userNo': 2622344,
#   'agentId': 2622344,
#   'agentName': 'e편한중앙공인중개사',
#   'agentTel': '02-6732-4989',
#   'agentUserName': '김수연',
#   'agentPhone': '01066770024',
#   'created_at': '2019-11-01 16:38:30',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/2952/6353/1e62e6ed53cb4b2284ecf7b9280d3970.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 83, 'p': 25},
#   'isNew': True,
#   'sales': 84000},
#  {'itemId': 18711803,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '18',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54473232045174,
#   'lng': 126.94257048117984,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '내부 깔금, 염리초 배정',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T00:59:48.000Z',
#   'apartmentId': 2952,
#   'apartmentName': '대흥태영',
#   'buildingName': '114동',
#   'roomTypeId': 6351,
#   'grossAreaName': {'m2': 109, 'p': 32},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/2952/6351/07cb1a3b07f04790819823f0777f6024.png',
#   'userNo': 2622344,
#   'agentId': 2622344,
#   'agentName': 'e편한중앙공인중개사',
#   'agentTel': '02-6732-4989',
#   'agentUserName': '김수연',
#   'agentPhone': '01066770024',
#   'created_at': '2019-11-01 16:39:41',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/2952/6351/07cb1a3b07f04790819823f0777f6024.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 109, 'p': 32},
#   'isNew': True,
#   'sales': 102000},
#  {'itemId': 18711875,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '18',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54473232045174,
#   'lng': 126.94257048117984,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': ' 염리초, 인기 아파트, 대중교통 편리',
#   'agentNo': None,
#   'regDate': '2019-11-09',
#   'regTime': '2019-11-09T00:59:48.000Z',
#   'apartmentId': 2952,
#   'apartmentName': '대흥태영',
#   'buildingName': '114동',
#   'roomTypeId': 6351,
#   'grossAreaName': {'m2': 109, 'p': 32},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/2952/6351/07cb1a3b07f04790819823f0777f6024.png',
#   'userNo': 2622344,
#   'agentId': 2622344,
#   'agentName': 'e편한중앙공인중개사',
#   'agentTel': '02-6732-4989',
#   'agentUserName': '김수연',
#   'agentPhone': '01066770024',
#   'created_at': '2019-11-01 16:42:16',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/2952/6351/07cb1a3b07f04790819823f0777f6024.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 109, 'p': 32},
#   'isNew': True,
#   'sales': 115000}]

# %%
item_df= pd.DataFrame(datas)
item_df. tail()
# Out:
#      agentId   agentName  agentNo   agentPhone      agentTel agentUserName  \
# 195  2622344  e편한중앙공인중개사      NaN  01066770024  02-6732-4989           김수연
# 196  2622344  e편한중앙공인중개사      NaN  01066770024  02-6732-4989           김수연
# 197  2622344  e편한중앙공인중개사      NaN  01066770024  02-6732-4989           김수연
# 198  2622344  e편한중앙공인중개사      NaN  01066770024  02-6732-4989           김수연
# 199  2622344  e편한중앙공인중개사      NaN  01066770024  02-6732-4989           김수연
#
#          agreementArea     agreementAreaName  apartmentId apartmentName  ...  \
# 195  {'m2': 0, 'p': 0}  {'m2': 109, 'p': 32}         2952          대흥태영  ...
# 196  {'m2': 0, 'p': 0}   {'m2': 83, 'p': 25}         2952          대흥태영  ...
# 197  {'m2': 0, 'p': 0}   {'m2': 83, 'p': 25}         2952          대흥태영  ...
# 198  {'m2': 0, 'p': 0}  {'m2': 109, 'p': 32}         2952          대흥태영  ...
# 199  {'m2': 0, 'p': 0}  {'m2': 109, 'p': 32}         2952          대흥태영  ...
#
#                       regTime rent roomTypeId   sales        sectionType type  \
# 195  2019-11-09T00:59:48.000Z    0       6351  107000  premium_recommend   매매
# 196  2019-11-09T00:59:48.000Z    0       6353   78000  premium_recommend   매매
# 197  2019-11-09T00:59:48.000Z    0       6353   84000  premium_recommend   매매
# 198  2019-11-09T00:59:48.000Z    0       6351  102000  premium_recommend   매매
# 199  2019-11-09T00:59:48.000Z    0       6351  115000  premium_recommend   매매
#
#       userNo viewType vr_request_id  vr_status
# 195  2622344        1          None       None
# 196  2622344        1          None       None
# 197  2622344        1          None       None
# 198  2622344        1          None       None
# 199  2622344        1          None       None
#
# [5 rows x 39 columns]

# %%
#pandas option 설정
pd.options.display.max_columns = len(item_df.columns)

# %%
item_df.tail(2)
# Out:
#      agentId   agentName  agentNo   agentPhone      agentTel agentUserName  \
# 198  2622344  e편한중앙공인중개사      NaN  01066770024  02-6732-4989           김수연
# 199  2622344  e편한중앙공인중개사      NaN  01066770024  02-6732-4989           김수연
#
#          agreementArea     agreementAreaName  apartmentId apartmentName  \
# 198  {'m2': 0, 'p': 0}  {'m2': 109, 'p': 32}         2952          대흥태영
# 199  {'m2': 0, 'p': 0}  {'m2': 109, 'p': 32}         2952          대흥태영
#
#     buildingFloor buildingName           created_at exclusive_type  \
# 198            18         114동  2019-11-01 16:39:41              1
# 199            18         114동  2019-11-01 16:42:16              1
#
#                                              floorPlan             grossArea  \
# 198  https://ic.zigbang.com/ic/floorplan/2952/6351/...  {'m2': 109, 'p': 32}
# 199  https://ic.zigbang.com/ic/floorplan/2952/6351/...  {'m2': 109, 'p': 32}
#
#             grossAreaName groupedItemFloor house_key  isNew    itemId  \
# 198  {'m2': 109, 'p': 32}               저층      None   True  18711803
# 199  {'m2': 109, 'p': 32}               고층      None   True  18711875
#
#                                              itemImage itemImages  \
# 198  [https://ic.zigbang.com/ic/floorplan/2952/6351...       None
# 199  [https://ic.zigbang.com/ic/floorplan/2952/6351...       None
#
#                  itemTitle        lat        lng              netArea  \
# 198          내부 깔금, 염리초 배정  37.544732  126.94257  {'m2': 84, 'p': 25}
# 199   염리초, 인기 아파트, 대중교통 편리  37.544732  126.94257  {'m2': 84, 'p': 25}
#
#     real_type     regDate                   regTime  rent  roomTypeId   sales  \
# 198       아파트  2019-11-09  2019-11-09T00:59:48.000Z     0        6351  102000
# 199       아파트  2019-11-09  2019-11-09T00:59:48.000Z     0        6351  115000
#
#            sectionType type   userNo  viewType vr_request_id vr_status
# 198  premium_recommend   매매  2622344         1          None      None
# 199  premium_recommend   매매  2622344         1          None      None

# %%
columns= ["itemId","buildingFloor","groupedItemFloor","grossArea","lat","lng","sales","itemTitle"]
item_df=item_df[columns]
item_df.tail(2)
# Out:
#        itemId buildingFloor groupedItemFloor             grossArea        lat  \
# 198  18711803            18               저층  {'m2': 109, 'p': 32}  37.544732
# 199  18711875            18               고층  {'m2': 109, 'p': 32}  37.544732
#
#            lng   sales              itemTitle
# 198  126.94257  102000          내부 깔금, 염리초 배정
# 199  126.94257  115000   염리초, 인기 아파트, 대중교통 편리

# %%
item_df["m2"]= item_df["grossArea"].apply(lambda data:data["m2"])
item_df["p"]= item_df["grossArea"].apply(lambda data:data["p"])
item_df.drop(columns = ["grossArea"], inplace=True)

# %%
item_df.tail(3)
# Out:
#        itemId buildingFloor groupedItemFloor        lat        lng   sales  \
# 197  18711754            22               고층  37.544732  126.94257   84000
# 198  18711803            18               저층  37.544732  126.94257  102000
# 199  18711875            18               고층  37.544732  126.94257  115000
#
#                  itemTitle   m2   p
# 197        내부 수리상태 양호 깨끗해요   83  25
# 198          내부 깔금, 염리초 배정  109  32
# 199   염리초, 인기 아파트, 대중교통 편리  109  32

# %% [markdown]
# ####  함수로 만들기

# %%
def crawling_apt(addr):
    #동이름 -> 위도, 경도
    url = "https://apis.zigbang.com/search?q={}".format(addr)
    response = requests.get(url)
    datas = response.json()["items"][0]
    lat,lng =datas["lat"],datas["lng"]
    
    #위도 경도-> geohash
    geohash= geohash2.encode(lat,lng,precision=5)
    #geohash -> ids
    url = "https://apis.zigbang.com/property/apartments/items?\
domain=zigbang&geohash={}\
&q=type=sales%7Cprice=0~-1%7CfloorArea=0~-1".format(geohash)
    response = requests.get(url)
    datas = response.json()["items"]
    ids = [data["itemId"] for data in datas]
    
    #ids -> items : 200개씩
    dfs=[]
    for idx in range(0,len(ids),200):
        start, end = idx, idx+200
        ids_str = str(ids[start:end]).replace(" ","")
        url = "https://apis.zigbang.com/property/apartments/items?\
        vritemIds={ids}&itemIds={ids}&citemIds={ids}".format(ids=ids_str)
        response = requests.get(url)
        datas = response.json()["items"]
        item_df = pd.DataFrame(datas)
        columns = [ "itemId", "buildingFloor", "groupedItemFloor", "grossArea", "lat", "lng", "sales", "itemTitle" ]
        item_df = item_df[columns]
        item_df["m2"] = item_df["grossArea"].apply(lambda data: data["m2"])
        item_df["p"] = item_df["grossArea"].apply(lambda data: data["p"])
        item_df.drop(columns=["grossArea"], inplace=True)
        dfs.append(item_df)
    result_df = pd.concat(dfs)
    result_df.reset_index(drop=True, inplace=True)
    return result_df

# %%
crawling_apt("성수동").tail()
# Out:
#         itemId buildingFloor groupedItemFloor        lat         lng   sales  \
# 2381  17393716            15               고층  37.546677  127.026643  145000
# 2382  18425015            25               저층  37.568861  127.027945  123000
# 2383  18425104            25               고층  37.568861  127.027945  123000
# 2384  18414690            21               중층  37.568878  127.031898   85000
# 2385  18408870            25               중층  37.570465  127.024673  118000
#
#                             itemTitle   m2   p
# 2381           응봉산조망 올확장 시스템에어컨 세안고매매  111  33
# 2382       올확장되어있으며, 상왕십리역과 가가운 동입니다.  107  32
# 2383              단지내 정원뷰입니다. 에어컨있습니다  107  32
# 2384                       집상태 깨끗한 물건  107  32
# 2385  시세보다 저렴한 가격으로 투자하기 좋아요 현재 전세거주중  107  32

# %%
# 도곡동에서 30층 이상되는 아파트의 고층 매물을 찾아서 구매

# %%
items_df= crawling_apt("도곡동")
items_df.tail()
# Out:
#        itemId buildingFloor groupedItemFloor        lat         lng   sales  \
# 689  18013640          None             None  37.491580  127.029970   91000
# 690  18013665          None             None  37.493337  127.026873  210000
# 691  18013793          None             None  37.493337  127.026873  250000
# 692  18464087            30               저층  37.493337  127.026873  215000
# 693  18385710            15             None  37.492310  127.035778  170000
#
#                     itemTitle   m2   p
# 689       강남역 신축 아파트 전세 6억2천   103  31
# 690             강남역 신축 아파트 저층  111  33
# 691                강남역 신축 아파트  144  43
# 692           전세 안고 매매 가능 매물   111  33
# 693  **실입주가능  **입주정상  **로얄층    183  55

# %%
items_df.dtypes
# Out:
# itemId                int64
# buildingFloor        object
# groupedItemFloor     object
# lat                 float64
# lng                 float64
# sales                 int64
# itemTitle            object
# m2                    int64
# p                     int64
# dtype: object

# %%
# items_df[items_df["buildingFloor"]]>=30 할 수 없음.(빈칸도 있고, int가 아니여서 연산불가)

items_df = items_df[items_df["buildingFloor"].notnull()]
items_df.reset_index(drop=True, inplace=True)
items_df.tail(2)
# Out:
#        itemId buildingFloor groupedItemFloor        lat         lng   sales  \
# 678  18464087            30               저층  37.493337  127.026873  215000
# 679  18385710            15             None  37.492310  127.035778  170000
#
#                     itemTitle   m2   p
# 678           전세 안고 매매 가능 매물   111  33
# 679  **실입주가능  **입주정상  **로얄층    183  55

# %%
items_df["buildingFloor"] = items_df["buildingFloor"].astype("int")

# %%
result_df= items_df[
    (items_df["buildingFloor"]>=30) &
    (items_df["groupedItemFloor"] == "고층")
]
len(result_df)
# Out:
# 95

# %%
np.average(result_df["sales"])
# Out:
# 230505.26315789475

# %%
# %%writefile zigbang.py
import pandas as pd
import requests
import geohash2

def crawling_apt(addr):
    #동이름 -> 위도, 경도
    url = "https://apis.zigbang.com/search?q={}".format(addr)
    response = requests.get(url)
    datas = response.json()["items"][0]
    lat,lng =datas["lat"],datas["lng"]
    
    #위도 경도-> geohash
    geohash= geohash2.encode(lat,lng,precision=5)
    #geohash -> ids
    url = "https://apis.zigbang.com/property/apartments/items?\
domain=zigbang&geohash={}\
&q=type=sales%7Cprice=0~-1%7CfloorArea=0~-1".format(geohash)
    response = requests.get(url)
    datas = response.json()["items"]
    ids = [data["itemId"] for data in datas]
    
    #ids -> items : 200개씩
    dfs=[]
    for idx in range(0,len(ids),200):
        start, end = idx, idx+200
        ids_str = str(ids[start:end]).replace(" ","")
        url = "https://apis.zigbang.com/property/apartments/items?\
        vritemIds={ids}&itemIds={ids}&citemIds={ids}".format(ids=ids_str)
        response = requests.get(url)
        datas = response.json()["items"]
        item_df = pd.DataFrame(datas)
        columns = [ "itemId", "buildingFloor", "groupedItemFloor", "grossArea", "lat", "lng", "sales", "itemTitle" ]
        item_df = item_df[columns]
        item_df["m2"] = item_df["grossArea"].apply(lambda data: data["m2"])
        item_df["p"] = item_df["grossArea"].apply(lambda data: data["p"])
        item_df.drop(columns=["grossArea"], inplace=True)
        dfs.append(item_df)
    result_df = pd.concat(dfs)
    result_df.reset_index(drop=True, inplace=True)
    return result_df
# Out:
# Overwriting zigbang.py
