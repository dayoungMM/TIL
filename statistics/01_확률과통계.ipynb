# %%
### 확률론
- 빈도주의 관점: 반복적으로 선택된 표본이 사건(부분집합) A의 원소가 될 경향
- 베이지안 관점 : 주장에 대한 신뢰도

# %% [markdown]
# #### 연습문제
# 1. 다섯개의 문자 a,a,a,b,b를 모두 일렬로 배열하는 방법의 수

# %%
(5*4*3*2*1)/(3*2*1*2*1)
# Out:
# 10.0

# %% [markdown]
# 2. 숫자 1,2,3을 사용하여 만들 수 있는 네자리 정수의 개수(단, 한 숫자는 여러번 사용 가능)

# %%
3*3*3*3
# Out:
# 81

# %% [markdown]
# 3. 서로 다른 5통의 편지를 A,B,C의 세 우체통에 넣는 방법의 수

# %%
# 3C1**5
((3*2*1/(1*2*1))**5)
# Out:
# 243.0

# %% [markdown]
# 4. 남자 5명, 여자 3명중에서 남자3명, 여자2명의 임원 선출하는 방법의수

# %%
# 5C3 * 3C2
((5*4*3*2*1)/(3*2*1*2*1))*((3*2*1)/(2*1*1))
# Out:
# 30.0

# %% [markdown]
# 5. 6명의 선거인이 2명의 후보자에게 무기명으로 투표하는 방법의 수

# %% [markdown]
# (0,6),(1,5),(2,4),(3,3),(4,2),(5,1),(6,0)

# %% [markdown]
# #### 참고
# $Pr(K=k)=f(k;n,p)={n \choose k}p^{k}(1-p)^{{n-k}}$
#
# ${n \choose k}={\frac  {n!}{k!(n-k)!}}$
#
# 이항 계수(C(n,k) 또는 nCk라고 쓰기도 함). 이 식은 다음과 같이 이해할 수 있다: 우리는 k번의 성공(pk)과 n − k번의 실패((1 − p)n − k)를 원한다. 그러나, k번의 성공은 n번의 시도 중 어디서든지 발생할 수 있고, 또한 k번의 성공을 가지는 분포는 C(n, k)개가 있다.

# %% [markdown]
# # 경우의수
# - 합의 법칙: OR (사건 A,B가 동시에 일어나지 않을때)
# - 곱의 법칙: AND (사건 A,B가 동시에 일어날 때 )

# %% [markdown]
# - 순서가 있는 선택: 순열
# - 순서가 없는 선택: 조합

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 원순열
# - 서로다른 n개의 원소를 원형으로 배열하는 것
# - ABCD, BCDA, CDAB, DABC
# = (n-1)!
# = $nPc/r$

# %% [markdown]
# ## 중복순열
# - 서로 다른 n개의 중복을 허용하여 r개를 택하여 일렬로 나열하는 방법
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 조합
# - 서로 다른 n개에서 순서를 생각하지 않고 r개를 택하는 것
# ![image.png](attachment:image.png)

# %%
from scipy.special import comb
comb(15, 5, exact=True) * comb(10, 5, exact=True)  /(3*2*1)
# Out:
# 126126.0

# %%
comb(6, 3, exact=True)
# Out:
# 20

# %% [markdown]
# ### 연습문제
# 1. 6명의 학생을 a,b,c팀으로 2명씩 나누는 방법의 수

# %%
# 6C2*4C2*2C2
comb(6, 2, exact=True)*comb(4, 2, exact=True)
# Out:
# 90

# %% [markdown]
# 2. 여자6명, 남자4명중에서 4명을 선출할 때 적어도 남자 1명이 포함되는 경우의수

# %%
#10C4 - 6C4
# 모든 경우의수 - 여자만 선발될때의 경우의수
comb(10,4)- comb(6,4)
# Out:
# 195.0

# %%
comb(4,1)*comb(9,3)
# Out:
# 1.7230769230769232

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#위1아래2
a = comb(3,1)*comb(4,2)
#위2 아래1
b = comb(3,2)*comb(4,1)
#위3
c= comb(3,3)

a+b+c
# Out:
# 31.0

# %%
#7C3-4C3
comb(7,3)-comb(4,3)
# Out:
# 31.0

# %% [markdown]
# ### 확률 연습문제
# 1. 20장의 복권 중에 당첨 복권이 4장이 들어있다. 이중에 2장의 복권을 샀을대 2장 모두 당첨될 확률

# %%
comb(4,2)/comb(20,2)
# Out:
# 0.031578947368421054

# %% [markdown]
# 2. 남자 6명, 여자 4명 중에서 위원 4명을 뽑을 때 남자 2명, 여자 2명이 뽑 힐 확률은?

# %%
comb(6,2)*comb(4,2)/comb(10,4)
# Out:
# 0.42857142857142855

# %% [markdown]
# 3. 한 줄로 6명이 설 때, 특정한 3사람이 이웃하게 될 확률은?

# %%
((4*3*2*1)*(3*2*1) )/(6*5*4*3*2*1)
# Out:
# 0.2

# %% [markdown]
# 4. 흰 구슬 8개와 붉은 구슬 5개가 들어 있는 주머니에서 3 개를 꺼낼 때, 모두 같은 색일 확률은?

# %%
(comb(8,3)+comb(5,3))/comb(13,3)
# Out:
# 0.23076923076923078

# %% [markdown]
# 5. 10개의 제비 중에서 당첨이 4개 들어있다. 처음에 갑이 1개를 꺼내고, 다음에 을이 한 개를 꺼낼 때 을이 당첨을 뽑을 확률은?

# %%
#갑을 모두 당첨 + 을만 당첨
(4*3+6*4)/(10*9)
# Out:
# 0.4

# %% [markdown]
# ### 확률의 덧셈정리
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 조건부 확률
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 확률의 곱셈정리
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
